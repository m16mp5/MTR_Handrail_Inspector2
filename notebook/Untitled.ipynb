# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import genfromtxt
import pandas as pd
from matplotlib import cm
from matplotlib.ticker import LinearLocator

# 4, 6
df = pd.read_csv ('z_val_mm-006.csv')
slicedDF = df.iloc[:,300:2500]
minPtX = slicedDF.min(axis=0)
minPtY = slicedDF.min(axis=1)
handrailSurfaceLvX = slicedDF.median(axis=0)
handrailSurfaceLvY = slicedDF.median(axis=1)

print(slicedDF.shape)
print(minPtX.shape)
print(minPtY.shape)
print(handrailSurfaceLvX.median())
print(handrailSurfaceLvY.median())

fig = plt.figure(figsize=(24, 18))
plt.subplot(3, 1, 1)

ax.set_title('Handrail Defect')
plt.imshow(slicedDF.T, interpolation='nearest', aspect='auto')
plt.colorbar(orientation='vertical')


plt.subplot(3, 1, 2)
plt.plot(minPtX)

plt.subplot(3, 1, 3)
plt.plot(minPtY)

plt.show()
# Out:
# (2999, 2200)
# (2200,)
# (2999,)
# 3.844
# 3.844
